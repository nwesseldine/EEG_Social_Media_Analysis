# %%
import os, sys
import numpy as np
import datetime
from EEG_feature_extraction import generate_feature_vectors_from_samples

# %%
#This is the generating matrix code for the original github data
def gen_training_matrix(directory_path, output_file, cols_to_ignore):
	# Initialise return matrix
	FINAL_MATRIX = None
	
	for x in os.listdir(directory_path):

		# Ignore non-CSV files
		if not x.lower().endswith('.csv'):
			continue
		
		# For safety we'll ignore files containing the substring "test". 
		# [Test files should not be in the dataset directory in the first place]
		if 'test' in x.lower():
			continue
		try:
			name, state, _ = x[:-4].split('-')
		except:
			print ('Wrong file name', x)
			sys.exit(-1)
		if state.lower() == 'concentrating':
			state = 2.
		elif state.lower() == 'neutral':
			state = 1.
		elif state.lower() == 'relaxed':
			state = 0.
		else:
			print ('Wrong file name', x)
			sys.exit(-1)
			
		print ('Using file', x)
		full_file_path = directory_path  +   '/'   + x
		vectors, header = generate_feature_vectors_from_samples(file_path = full_file_path, 
														        nsamples = 150, 
																period = 1.,
																state = state,
														        remove_redundant = True,
																cols_to_ignore = cols_to_ignore)
		
		print ('resulting vector shape for the file', vectors.shape)
		
		
		if FINAL_MATRIX is None:
			FINAL_MATRIX = vectors
		else:
			FINAL_MATRIX = np.vstack( [ FINAL_MATRIX, vectors ] )

	print ('FINAL_MATRIX', FINAL_MATRIX.shape)
	
	# Shuffle rows
	# np.random.shuffle(FINAL_MATRIX)
	
	# Save to file
	np.savetxt(output_file, FINAL_MATRIX, delimiter = ',',
			header = ','.join(header), 
			comments = '')

	return None


if __name__ == '__main__':
	
	
	# if len(sys.argv) < 3: # For use in calling the function from the command line
	# 	print ('arg1: input dir\narg2: output file')
	# 	sys.exit(-1)

	date = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M')

	target_dir = "original_data" # Change this one to change which data we're processing
	directory_path = "../cleaned datasets/" + target_dir

	output_file = f"../featuresets/{target_dir}_{date}.csv"
    
	gen_training_matrix(directory_path, output_file, cols_to_ignore = -1)
# Out:
# Using file name-concentrating-1.csv
# resulting vector shape for the file (116, 989)
# Using file subjecta-concentrating-1.csv
# resulting vector shape for the file (116, 989)
# Using file subjecta-concentrating-2.csv
# resulting vector shape for the file (102, 989)
# Using file subjecta-neutral-1.csv
# resulting vector shape for the file (116, 989)
# Using file subjecta-neutral-2.csv
# resulting vector shape for the file (117, 989)
# Using file subjecta-relaxed-1.csv
# resulting vector shape for the file (116, 989)
# Using file subjecta-relaxed-2.csv
# resulting vector shape for the file (116, 989)
# Using file subjectb-concentrating-1.csv
# resulting vector shape for the file (86, 989)
# Using file subjectb-concentrating-2.csv
# resulting vector shape for the file (87, 989)
# Using file subjectb-neutral-1.csv
# resulting vector shape for the file (117, 989)
# Using file subjectb-neutral-2.csv
# resulting vector shape for the file (116, 989)
# Using file subjectb-relaxed-1.csv
# resulting vector shape for the file (116, 989)
# Using file subjectb-relaxed-2.csv
# resulting vector shape for the file (6, 989)
# Using file subjectc-concentrating-1.csv
# resulting vector shape for the file (116, 989)
# Using file subjectc-concentrating-2.csv
# resulting vector shape for the file (116, 989)
# Using file subjectc-neutral-1.csv
# resulting vector shape for the file (116, 989)
# Using file subjectc-neutral-2.csv
# resulting vector shape for the file (16, 989)
# Using file subjectc-relaxed-1.csv
# resulting vector shape for the file (116, 989)
# Using file subjectc-relaxed-2.csv
# resulting vector shape for the file (117, 989)
# Using file subjectd-concentrating-1.csv
# resulting vector shape for the file (86, 989)
# Using file subjectd-concentrating-2.csv
# resulting vector shape for the file (5, 989)
# Using file subjectd-neutral-1.csv
# resulting vector shape for the file (116, 989)
# Using file subjectd-neutral-2.csv
# resulting vector shape for the file (116, 989)
# Using file subjectd-relaxed-1.csv
# resulting vector shape for the file (116, 989)
# Using file subjectd-relaxed-2.csv
# resulting vector shape for the file (116, 989)
# FINAL_MATRIX (2479, 989)

# %%
# This is the generating matrix code for Mendeley Data

def gen_training_matrix(directory_path, output_file, cols_to_ignore):
	# Initialise return matrix
	FINAL_MATRIX = None
	
	for x in os.listdir(directory_path):

		# Ignore non-CSV files
		if not x.lower().endswith('.csv'):
			continue
		
		# For safety we'll ignore files containing the substring "test". 
		# [Test files should not be in the dataset directory in the first place]
		if 'test' in x.lower():
			continue
		try:
			name, _ ,state, _ = x[:-4].split('-')
		except:
			print ('Wrong file name', x)
			sys.exit(-1)
		if state.lower() == '1':
			state = 1.
		elif state.lower() == '2':
			state = 2.
		elif state.lower() == '3':
			state = 3.
		else:
			print ('Wrong file name', x)
			sys.exit(-1)
			
		print ('Using file', x)
		full_file_path = directory_path  +   '/'   + x
		vectors, header = generate_feature_vectors_from_samples(file_path = full_file_path, 
														        nsamples = 150, 
																period = 1.,
																state = state,
														        remove_redundant = True,
																cols_to_ignore = cols_to_ignore)
		
		print ('resulting vector shape for the file', vectors.shape)
		
		
		if FINAL_MATRIX is None:
			FINAL_MATRIX = vectors
		else:
			FINAL_MATRIX = np.vstack( [ FINAL_MATRIX, vectors ] )

	print ('FINAL_MATRIX', FINAL_MATRIX.shape)
	
	# Shuffle rows
	# np.random.shuffle(FINAL_MATRIX)
	
	# Save to file
	np.savetxt(output_file, FINAL_MATRIX, delimiter = ',',
			header = ','.join(header), 
			comments = '')

	return None


if __name__ == '__main__':
	
	
	# if len(sys.argv) < 3: # For use in calling the function from the command line
	# 	print ('arg1: input dir\narg2: output file')
	# 	sys.exit(-1)

	date = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M')

	target_dir = "Mendeley cleaned" # Change this one to change which data we're processing
	directory_path = "../cleaned datasets/" + target_dir

	output_file = f"../featuresets/{target_dir}_{date}.csv"
    
	gen_training_matrix(directory_path, output_file, cols_to_ignore = -1)
# Out:
# Using file subject1-label-1-cleaned.csv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 76
#      72 directory_path = "../cleaned datasets/" + target_dir
#      74 output_file = f"../featuresets/{target_dir}_{date}.csv"
# ---> 76 gen_training_matrix(directory_path, output_file, cols_to_ignore = -1)
#
# Cell In[8], line 34, in gen_training_matrix(directory_path, output_file, cols_to_ignore)
#      32 print ('Using file', x)
#      33 full_file_path = directory_path  +   '/'   + x
# ---> 34 vectors, header = generate_feature_vectors_from_samples(file_path = full_file_path,
#      35 												        nsamples = 150,
#      36 														period = 1.,
#      37 														state = state,
#      38 												        remove_redundant = True,
#      39 														cols_to_ignore = cols_to_ignore)
#      41 print ('resulting vector shape for the file', vectors.shape)
#      44 if FINAL_MATRIX is None:
#
# File c:\Users\nwess\OneDrive\Documentos\EEG_Research\EEG_Social_Media_Analysis\code\EEG_feature_extraction.py:847, in generate_feature_vectors_from_samples(file_path, nsamples, period, state, remove_redundant, cols_to_ignore)
#     841 while True:
#     842 	# Get the next slice from the file (starting at time 't', with a
#     843 	# duration of 'period'
#     844 	# If an exception is raised or the slice is not as long as we expected,
#     845 	# return the current data available
#     846 	try:
# --> 847 		s, dur = get_time_slice(matrix, start = t, period = period)
#     848 		if cols_to_ignore is not None:
#     849 			s = np.delete(s, cols_to_ignore, axis = 1)
#
# File c:\Users\nwess\OneDrive\Documentos\EEG_Research\EEG_Social_Media_Analysis\code\EEG_feature_extraction.py:69, in get_time_slice(full_matrix, start, period)
#      67 # Changed for greater efficiency [fcampelo]
#      68 rstart  = full_matrix[0, 0] + start
# ---> 69 index_0 = np.max(np.where(full_matrix[:, 0] <= rstart))
#      70 index_1 = np.max(np.where(full_matrix[:, 0] <= rstart + period))
#      72 duration = full_matrix[index_1, 0] - full_matrix[index_0, 0]
#
# File c:\Users\nwess\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:2810, in max(a, axis, out, keepdims, initial, where)
#    2692 @array_function_dispatch(_max_dispatcher)
#    2693 @set_module('numpy')
#    2694 def max(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2695          where=np._NoValue):
#    2696     """
#    2697     Return the maximum of an array or maximum along an axis.
#    2698
#    (...)
#    2808     5
#    2809     """
# -> 2810     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2811                           keepdims=keepdims, initial=initial, where=where)
#
# File c:\Users\nwess\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
#This is the genrating matrix code for our own data
def gen_training_matrix(directory_path, output_file, cols_to_ignore):
	# Initialise return matrix
	FINAL_MATRIX = None
	
	for x in os.listdir(directory_path):

		# Ignore non-CSV files
		if not x.lower().endswith('.csv'):
			continue
		
		# For safety we'll ignore files containing the substring "test". 
		# [Test files should not be in the dataset directory in the first place]
		if 'test' in x.lower():
			continue
		try:
			name, state, _ = x[:-4].split('-')
		except:
			print ('Wrong file name', x)
			sys.exit(-1)
		if state.lower() == 'Marshall':
			state = 2.
		elif state.lower() == 'Natalie':
			state = 1.
		elif state.lower() == 'Kenzo':
			state = 0.
		else:
			print ('Wrong file name', x)
			sys.exit(-1)
			
		print ('Using file', x)
		full_file_path = directory_path  +   '/'   + x
		vectors, header = generate_feature_vectors_from_samples(file_path = full_file_path, 
														        nsamples = 150, 
																period = 1.,
																state = None,
														        remove_redundant = True,
																cols_to_ignore = cols_to_ignore)
		
		print ('resulting vector shape for the file', vectors.shape)
		
		
		if FINAL_MATRIX is None:
			FINAL_MATRIX = vectors
		else:
			FINAL_MATRIX = np.vstack( [ FINAL_MATRIX, vectors ] )

	print ('FINAL_MATRIX', FINAL_MATRIX.shape)
	
	# Shuffle rows
	# np.random.shuffle(FINAL_MATRIX)
	
	# Save to file
	np.savetxt(output_file, FINAL_MATRIX, delimiter = ',',
			header = ','.join(header), 
			comments = '')

	return None


if __name__ == '__main__':
	
	
	# if len(sys.argv) < 3: # For use in calling the function from the command line
	# 	print ('arg1: input dir\narg2: output file')
	# 	sys.exit(-1)

	date = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M')

	target_dir = "local datasets" # Change this one to change which data we're processing
	directory_path = "../cleaned datasets/" + target_dir

	output_file = f"../featuresets/{target_dir}_{date}.csv"
    
	gen_training_matrix(directory_path, output_file, cols_to_ignore = -1)
