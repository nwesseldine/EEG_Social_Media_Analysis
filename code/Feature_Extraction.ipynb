# %%
import os, sys
import numpy as np
import datetime
import warnings
import re
import pandas as pd
from EEG_feature_extraction import generate_feature_vectors_from_samples

# %%
# Gets rid of pesky warnings about the logm not bein accurate, could be worth going back and looking at these later
warnings.filterwarnings(
    "ignore",
    message="logm result may be inaccurate*",
    category=RuntimeWarning
)

# %%
df = pd.read_csv("../featuresets/Emotion cleaned_2025-07-17_09-45.csv")

# %%
df = df.map(lambda x: x.real if isinstance(x, complex) else x)
print(df.iloc[2,3])
# Out:
#  (7.997485405219781569e+02+0.000000000000000000e+00j)

# %%
# Some code to practice natural sorting and see which files are missing a lot of information

path = "../cleaned datasets/Emotion cleaned/"

def natural_sort_key(s):
        return [int(text) if text.isdigit() else text.lower() for text in re.split('([0-9]+)', s)]

sorted_entries = sorted(os.listdir(path), key=natural_sort_key)
for entry in sorted_entries:
    file = pd.read_csv(os.path.join(path, entry))
    shape = file.shape
    print(entry, shape)
# Out:
# subject1-label-1-cleaned.csv (4146, 10)
# subject1-label-2-cleaned.csv (8872, 10)
# subject1-label-3-cleaned.csv (3473, 10)
# subject1-label-4-cleaned.csv (4832, 10)
# subject2-label-1-cleaned.csv (5053, 10)
# subject2-label-2-cleaned.csv (9481, 10)
# subject2-label-3-cleaned.csv (5065, 10)
# subject2-label-4-cleaned.csv (5124, 10)
# subject3-label-1-cleaned.csv (5111, 10)
# subject3-label-2-cleaned.csv (10219, 10)
# subject3-label-3-cleaned.csv (5092, 10)
# subject3-label-4-cleaned.csv (323, 10)
# subject4-label-1-cleaned.csv (4654, 10)
# subject4-label-2-cleaned.csv (9607, 10)
# subject4-label-3-cleaned.csv (4934, 10)
# subject4-label-4-cleaned.csv (4953, 10)
# subject5-label-1-cleaned.csv (5074, 10)
# subject5-label-2-cleaned.csv (10155, 10)
# subject5-label-3-cleaned.csv (5119, 10)
# subject5-label-4-cleaned.csv (5119, 10)
# subject6-label-1-cleaned.csv (3317, 10)
# subject6-label-2-cleaned.csv (9997, 10)
# subject6-label-3-cleaned.csv (5108, 10)
# subject6-label-4-cleaned.csv (5117, 10)
# subject7-label-1-cleaned.csv (4931, 10)
# subject7-label-2-cleaned.csv (9860, 10)
# subject7-label-3-cleaned.csv (5119, 10)
# subject7-label-4-cleaned.csv (5123, 10)
# subject8-label-1-cleaned.csv (5116, 10)
# subject8-label-2-cleaned.csv (10232, 10)
# subject8-label-3-cleaned.csv (5116, 10)
# subject8-label-4-cleaned.csv (5118, 10)
# subject9-label-1-cleaned.csv (5123, 10)
# subject9-label-2-cleaned.csv (10242, 10)
# subject9-label-3-cleaned.csv (5123, 10)
# subject9-label-4-cleaned.csv (5122, 10)
# subject10-label-1-cleaned.csv (4727, 10)
# subject10-label-2-cleaned.csv (9405, 10)
# subject10-label-3-cleaned.csv (4730, 10)
# subject10-label-4-cleaned.csv (1278, 10)
# subject11-label-1-cleaned.csv (4867, 10)
# subject11-label-2-cleaned.csv (8750, 10)
# subject11-label-3-cleaned.csv (2971, 10)
# subject11-label-4-cleaned.csv (1279, 10)
# subject12-label-1-cleaned.csv (5116, 10)
# subject12-label-2-cleaned.csv (10215, 10)
# subject12-label-3-cleaned.csv (5119, 10)
# subject12-label-4-cleaned.csv (4782, 10)
# subject13-label-1-cleaned.csv (1651, 10)
# subject13-label-2-cleaned.csv (5373, 10)
# subject13-label-3-cleaned.csv (1865, 10)
# subject13-label-4-cleaned.csv (4536, 10)
# subject14-label-1-cleaned.csv (2796, 10)
# subject14-label-2-cleaned.csv (9829, 10)
# subject14-label-3-cleaned.csv (5058, 10)
# subject14-label-4-cleaned.csv (5122, 10)
# subject15-label-1-cleaned.csv (4734, 10)
# subject15-label-2-cleaned.csv (10239, 10)
# subject15-label-3-cleaned.csv (5115, 10)
# subject15-label-4-cleaned.csv (5122, 10)
# subject16-label-1-cleaned.csv (5120, 10)
# subject16-label-2-cleaned.csv (10243, 10)
# subject16-label-3-cleaned.csv (5114, 10)
# subject16-label-4-cleaned.csv (5121, 10)
# subject17-label-1-cleaned.csv (4514, 10)
# subject17-label-2-cleaned.csv (10230, 10)
# subject17-label-3-cleaned.csv (5115, 10)
# subject17-label-4-cleaned.csv (5121, 10)
# subject18-label-1-cleaned.csv (3168, 10)
# subject18-label-2-cleaned.csv (9825, 10)
# subject18-label-3-cleaned.csv (4608, 10)
# subject18-label-4-cleaned.csv (5104, 10)
# subject19-label-1-cleaned.csv (4641, 10)
# subject19-label-2-cleaned.csv (9729, 10)
# subject19-label-3-cleaned.csv (5113, 10)
# subject19-label-4-cleaned.csv (5116, 10)
# subject20-label-1-cleaned.csv (4944, 10)
# subject20-label-2-cleaned.csv (9805, 10)
# subject20-label-3-cleaned.csv (4304, 10)
# subject20-label-4-cleaned.csv (4565, 10)
# subject21-label-1-cleaned.csv (526, 10)
# subject21-label-2-cleaned.csv (9541, 10)
# subject21-label-3-cleaned.csv (2342, 10)
# subject21-label-4-cleaned.csv (1984, 10)
# subject22-label-1-cleaned.csv (4272, 10)
# subject22-label-2-cleaned.csv (9811, 10)
# subject22-label-3-cleaned.csv (4912, 10)
# subject22-label-4-cleaned.csv (5081, 10)
# subject23-label-1-cleaned.csv (4822, 10)
# subject23-label-2-cleaned.csv (9495, 10)
# subject23-label-3-cleaned.csv (4723, 10)
# subject23-label-4-cleaned.csv (1280, 10)
# subject24-label-1-cleaned.csv (3608, 10)
# subject24-label-2-cleaned.csv (7837, 10)
# subject24-label-3-cleaned.csv (3619, 10)
# subject24-label-4-cleaned.csv (4869, 10)
# subject25-label-1-cleaned.csv (2399, 10)
# subject25-label-2-cleaned.csv (9418, 10)
# subject25-label-3-cleaned.csv (4886, 10)
# subject25-label-4-cleaned.csv (5121, 10)
# subject26-label-1-cleaned.csv (3891, 10)
# subject26-label-2-cleaned.csv (4736, 10)
# subject26-label-3-cleaned.csv (0, 10)
# subject26-label-4-cleaned.csv (4911, 10)
# subject27-label-1-cleaned.csv (4687, 10)
# subject27-label-2-cleaned.csv (10164, 10)
# subject27-label-3-cleaned.csv (4806, 10)
# subject27-label-4-cleaned.csv (4799, 10)
# subject28-label-1-cleaned.csv (4938, 10)
# subject28-label-2-cleaned.csv (10052, 10)
# subject28-label-3-cleaned.csv (4751, 10)
# %% [markdown]
# subject1-label-1-cleaned.csv (8906, 10)
# subject1-label-2-cleaned.csv (41748, 10)
# subject1-label-3-cleaned.csv (25854, 10)
# subject1-label-4-cleaned.csv (19851, 10)
# subject2-label-1-cleaned.csv (9907, 10)
# subject2-label-2-cleaned.csv (49644, 10)
# subject2-label-3-cleaned.csv (39290, 10)
# subject2-label-4-cleaned.csv (21150, 10)
# subject3-label-1-cleaned.csv (10096, 10)
# subject3-label-2-cleaned.csv (50387, 10)
# subject3-label-3-cleaned.csv (38993, 10)
# subject3-label-4-cleaned.csv (402, 10)
# subject4-label-1-cleaned.csv (9671, 10)
# subject4-label-2-cleaned.csv (46625, 10)
# subject4-label-3-cleaned.csv (35368, 10)
# subject4-label-4-cleaned.csv (20382, 10)
# subject5-label-1-cleaned.csv (10242, 10)
# subject5-label-2-cleaned.csv (49690, 10)
# subject5-label-3-cleaned.csv (39323, 10)
# subject5-label-4-cleaned.csv (21167, 10)
# subject6-label-1-cleaned.csv (8023, 10)
# subject6-label-2-cleaned.csv (47085, 10)
# subject6-label-3-cleaned.csv (37658, 10)
# subject6-label-4-cleaned.csv (20803, 10)
# subject7-label-1-cleaned.csv (9884, 10)
# subject7-label-2-cleaned.csv (49260, 10)
# subject7-label-3-cleaned.csv (39407, 10)
# subject7-label-4-cleaned.csv (16931, 10)
# subject8-label-1-cleaned.csv (10135, 10)
# subject8-label-2-cleaned.csv (50164, 10)
# subject8-label-3-cleaned.csv (38361, 10)
# subject8-label-4-cleaned.csv (21325, 10)
# subject9-label-1-cleaned.csv (12040, 10)
# subject9-label-2-cleaned.csv (49076, 10)
# subject9-label-3-cleaned.csv (39462, 10)
# subject9-label-4-cleaned.csv (21348, 10)
# subject10-label-1-cleaned.csv (9560, 10)
# subject10-label-2-cleaned.csv (47976, 10)
# subject10-label-3-cleaned.csv (36908, 10)
# subject10-label-4-cleaned.csv (3307, 10)
# subject11-label-1-cleaned.csv (9890, 10)
# subject11-label-2-cleaned.csv (44235, 10)
# subject11-label-3-cleaned.csv (35672, 10)
# subject11-label-4-cleaned.csv (12738, 10)
# subject12-label-1-cleaned.csv (10147, 10)
# subject12-label-2-cleaned.csv (50457, 10)
# subject12-label-3-cleaned.csv (39604, 10)
# subject12-label-4-cleaned.csv (20971, 10)
# subject13-label-1-cleaned.csv (5370, 10)
# subject13-label-2-cleaned.csv (21704, 10)
# subject13-label-3-cleaned.csv (18927, 10)
# subject13-label-4-cleaned.csv (15287, 10)
# subject14-label-1-cleaned.csv (7748, 10)
# subject14-label-2-cleaned.csv (48083, 10)
# subject14-label-3-cleaned.csv (38603, 10)
# subject14-label-4-cleaned.csv (21270, 10)
# subject15-label-1-cleaned.csv (9739, 10)
# subject15-label-2-cleaned.csv (50474, 10)
# subject15-label-3-cleaned.csv (39850, 10)
# subject15-label-4-cleaned.csv (21630, 10)
# subject16-label-1-cleaned.csv (9961, 10)
# subject16-label-2-cleaned.csv (50352, 10)
# subject16-label-3-cleaned.csv (39441, 10)
# subject16-label-4-cleaned.csv (21368, 10)
# subject17-label-1-cleaned.csv (9314, 10)
# subject17-label-2-cleaned.csv (50601, 10)
# subject17-label-3-cleaned.csv (39562, 10)
# subject17-label-4-cleaned.csv (21447, 10)
# subject18-label-1-cleaned.csv (7942, 10)
# subject18-label-2-cleaned.csv (48188, 10)
# subject18-label-3-cleaned.csv (35524, 10)
# subject18-label-4-cleaned.csv (21248, 10)
# subject19-label-1-cleaned.csv (9571, 10)
# subject19-label-2-cleaned.csv (48481, 10)
# subject19-label-3-cleaned.csv (37851, 10)
# subject19-label-4-cleaned.csv (21332, 10)
# subject20-label-1-cleaned.csv (9874, 10)
# subject20-label-2-cleaned.csv (48227, 10)
# subject20-label-3-cleaned.csv (34187, 10)
# subject20-label-4-cleaned.csv (19504, 10)
# subject21-label-1-cleaned.csv (647, 10)
# subject21-label-2-cleaned.csv (47887, 10)
# subject21-label-3-cleaned.csv (21014, 10)
# subject21-label-4-cleaned.csv (6850, 10)
# subject22-label-1-cleaned.csv (9103, 10)
# subject22-label-2-cleaned.csv (48728, 10)
# subject22-label-3-cleaned.csv (37976, 10)
# subject22-label-4-cleaned.csv (21271, 10)
# subject23-label-1-cleaned.csv (9715, 10)
# subject23-label-2-cleaned.csv (46733, 10)
# subject23-label-3-cleaned.csv (35485, 10)
# subject23-label-4-cleaned.csv (3341, 10)
# subject24-label-1-cleaned.csv (7779, 10)
# subject24-label-2-cleaned.csv (38724, 10)
# subject24-label-3-cleaned.csv (26601, 10)
# subject24-label-4-cleaned.csv (19055, 10)
# subject25-label-1-cleaned.csv (6141, 10)
# subject25-label-2-cleaned.csv (48535, 10)
# subject25-label-3-cleaned.csv (38695, 10)
# subject25-label-4-cleaned.csv (20936, 10)
# subject26-label-1-cleaned.csv (8442, 10)
# subject26-label-2-cleaned.csv (20123, 10)
# subject26-label-3-cleaned.csv (0, 10)
# subject26-label-4-cleaned.csv (20025, 10)
# subject27-label-1-cleaned.csv (9515, 10)
# subject27-label-2-cleaned.csv (49499, 10)
# subject27-label-3-cleaned.csv (38164, 10)
# subject27-label-4-cleaned.csv (20666, 10)
# subject28-label-1-cleaned.csv (9460, 10)
# subject28-label-2-cleaned.csv (49427, 10)
# subject28-label-3-cleaned.csv (35658, 10)
# subject28-label-4-cleaned.csv (14332, 10)
# subject29-label-1-cleaned.csv (9538, 10)
# subject29-label-2-cleaned.csv (519, 10)
# subject29-label-3-cleaned.csv (23334, 10)
# subject29-label-4-cleaned.csv (19603, 10)
# subject30-label-1-cleaned.csv (7849, 10)
# subject30-label-2-cleaned.csv (47335, 10)
# subject30-label-3-cleaned.csv (35692, 10)
# subject30-label-4-cleaned.csv (20114, 10)
# subject31-label-1-cleaned.csv (9621, 10)
# subject31-label-2-cleaned.csv (48311, 10)
# subject31-label-3-cleaned.csv (35179, 10)
# subject31-label-4-cleaned.csv (19273, 10)
# subject32-label-1-cleaned.csv (8762, 10)
# subject32-label-2-cleaned.csv (46560, 10)
# subject32-label-3-cleaned.csv (33223, 10)
# subject32-label-4-cleaned.csv (20492, 10)
# subject33-label-1-cleaned.csv (9567, 10)
# subject33-label-2-cleaned.csv (47580, 10)
# subject33-label-3-cleaned.csv (36880, 10)
# subject33-label-4-cleaned.csv (20586, 10)
# subject34-label-1-cleaned.csv (65, 10)
# subject34-label-2-cleaned.csv (8523, 10)
# subject34-label-3-cleaned.csv (22494, 10)
# subject34-label-4-cleaned.csv (7519, 10)
# subject35-label-1-cleaned.csv (1545, 10)
# subject35-label-2-cleaned.csv (48373, 10)
# subject35-label-3-cleaned.csv (39332, 10)
# subject35-label-4-cleaned.csv (20672, 10)
# subject36-label-1-cleaned.csv (5430, 10)
# subject36-label-2-cleaned.csv (1417, 10)
# subject36-label-3-cleaned.csv (33741, 10)
# subject36-label-4-cleaned.csv (13890, 10)
# subject37-label-1-cleaned.csv (2585, 10)
# subject37-label-2-cleaned.csv (29184, 10)
# subject37-label-3-cleaned.csv (3765, 10)
# subject37-label-4-cleaned.csv (12203, 10)
# subject38-label-1-cleaned.csv (7752, 10)
# subject38-label-2-cleaned.csv (36669, 10)
# subject38-label-3-cleaned.csv (29499, 10)
# subject38-label-4-cleaned.csv (19914, 10)
# subject39-label-1-cleaned.csv (8066, 10)
# subject39-label-2-cleaned.csv (38351, 10)
# subject39-label-3-cleaned.csv (36279, 10)
# subject39-label-4-cleaned.csv (19178, 10)
# subject40-label-1-cleaned.csv (8623, 10)
# subject40-label-2-cleaned.csv (47999, 10)
# subject40-label-3-cleaned.csv (37833, 10)
# subject40-label-4-cleaned.csv (21375, 10)
# subject41-label-1-cleaned.csv (5640, 10)
# subject41-label-2-cleaned.csv (27725, 10)
# subject41-label-3-cleaned.csv (30420, 10)
# subject41-label-4-cleaned.csv (14562, 10)
# subject42-label-1-cleaned.csv (9079, 10)
# subject42-label-2-cleaned.csv (50380, 10)
# subject42-label-3-cleaned.csv (39612, 10)
# subject42-label-4-cleaned.csv (21374, 10)
# subject43-label-1-cleaned.csv (9968, 10)
# subject43-label-2-cleaned.csv (50293, 10)
# subject43-label-3-cleaned.csv (40107, 10)
# subject43-label-4-cleaned.csv (21342, 10)
# subject44-label-1-cleaned.csv (8142, 10)
# subject44-label-2-cleaned.csv (46463, 10)
# subject44-label-3-cleaned.csv (37242, 10)
# subject44-label-4-cleaned.csv (19402, 10)

# %%
#This is the generating matrix code for the original github data
def gen_training_matrix(directory_path, output_file, cols_to_ignore):
	# Initialise return matrix
	FINAL_MATRIX = None
	
	for x in os.listdir(directory_path):

		# Ignore non-CSV files
		if not x.lower().endswith('.csv'):
			continue
		
		# For safety we'll ignore files containing the substring "test". 
		# [Test files should not be in the dataset directory in the first place]
		if 'test' in x.lower():
			continue
		try:
			name, state, _ = x[:-4].split('-')
		except:
			print ('Wrong file name', x)
			sys.exit(-1)
		if state.lower() == 'concentrating':
			state = 2.
		elif state.lower() == 'neutral':
			state = 1.
		elif state.lower() == 'relaxed':
			state = 0.
		else:
			print ('Wrong file name', x)
			sys.exit(-1)
			
		print ('Using file', x)
		full_file_path = directory_path  +   '/'   + x
		vectors, header = generate_feature_vectors_from_samples(file_path = full_file_path, 
														        nsamples = 150, 
																period = 1.,
																state = state,
														        remove_redundant = True,
																cols_to_ignore = cols_to_ignore)
		
		print('resulting vector shape for the file', vectors.shape)
		
		
		if FINAL_MATRIX is None:
			FINAL_MATRIX = vectors
		else:
			FINAL_MATRIX = np.vstack( [ FINAL_MATRIX, vectors ] )

	print('FINAL_MATRIX', FINAL_MATRIX.shape)
	
	# Shuffle rows
	# np.random.shuffle(FINAL_MATRIX)
	
	# Save to file
	np.savetxt(output_file, FINAL_MATRIX, delimiter = ',',
			header = ','.join(header), 
			comments = '')

	return None


if __name__ == '__main__':
	
	
	# if len(sys.argv) < 3: # For use in calling the function from the command line
	# 	print ('arg1: input dir\narg2: output file')
	# 	sys.exit(-1)

	date = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M')

	target_dir = "original_data" # Change this one to change which data we're processing
	directory_path = "../cleaned datasets/" + target_dir

	output_file = f"../featuresets/{target_dir}_{date}.csv"
    
	gen_training_matrix(directory_path, output_file, cols_to_ignore = -1)
# Out:
# Using file name-concentrating-1.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjecta-concentrating-1.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjecta-concentrating-2.csv
# Slice too short break
# resulting vector shape for the file (102, 990)
# Using file subjecta-neutral-1.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjecta-neutral-2.csv
# Slice too short break
# resulting vector shape for the file (117, 990)
# Using file subjecta-relaxed-1.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjecta-relaxed-2.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjectb-concentrating-1.csv
# Slice too short break
# resulting vector shape for the file (86, 990)
# Using file subjectb-concentrating-2.csv
# Slice too short break
# resulting vector shape for the file (87, 990)
# Using file subjectb-neutral-1.csv
# Slice too short break
# resulting vector shape for the file (117, 990)
# Using file subjectb-neutral-2.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjectb-relaxed-1.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjectb-relaxed-2.csv
# Slice too short break
# resulting vector shape for the file (6, 990)
# Using file subjectc-concentrating-1.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjectc-concentrating-2.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjectc-neutral-1.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjectc-neutral-2.csv
# Slice too short break
# resulting vector shape for the file (16, 990)
# Using file subjectc-relaxed-1.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjectc-relaxed-2.csv
# Slice too short break
# resulting vector shape for the file (117, 990)
# Using file subjectd-concentrating-1.csv
# Slice too short break
# resulting vector shape for the file (86, 990)
# Using file subjectd-concentrating-2.csv
# Slice too short break
# resulting vector shape for the file (5, 990)
# Using file subjectd-neutral-1.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjectd-neutral-2.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjectd-relaxed-1.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjectd-relaxed-2.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# FINAL_MATRIX (2479, 990)

# %%
# This is the generating matrix code for Mendeley Data

def gen_training_matrix(directory_path, output_file, cols_to_ignore):
	# Initialise return matrix
	FINAL_MATRIX = None
	
	for x in os.listdir(directory_path):

		# Ignore non-CSV files
		if not x.lower().endswith('.csv'):
			continue
		
		# For safety we'll ignore files containing the substring "test". 
		# [Test files should not be in the dataset directory in the first place]
		if 'test' in x.lower():
			continue
		try:
			name, _ ,state, _ = x[:-4].split('-')
		except:
			print ('Wrong file name', x)
			sys.exit(-1)
		if state.lower() == '1':
			state = 1.
		elif state.lower() == '2':
			state = 2.
		elif state.lower() == '3':
			state = 3.
		else:
			print ('Wrong file name', x)
			sys.exit(-1)
			
		print ('Using file', x)
		full_file_path = directory_path  +   '/'   + x
		vectors, header = generate_feature_vectors_from_samples(file_path = full_file_path, 
														        nsamples = 150, 
																period = 1.,
																state = state,
														        remove_redundant = True,
																cols_to_ignore = cols_to_ignore)
		
		print ('resulting vector shape for the file', vectors.shape)
		
		
		if FINAL_MATRIX is None:
			FINAL_MATRIX = vectors
		else:
			FINAL_MATRIX = np.vstack( [ FINAL_MATRIX, vectors ] )

	print ('FINAL_MATRIX', FINAL_MATRIX.shape)
	
	# Shuffle rows
	# np.random.shuffle(FINAL_MATRIX)
	
	# Save to file
	np.savetxt(output_file, FINAL_MATRIX, delimiter = ',',
			header = ','.join(header), 
			comments = '')

	return None


if __name__ == '__main__':
	
	
	# if len(sys.argv) < 3: # For use in calling the function from the command line
	# 	print ('arg1: input dir\narg2: output file')
	# 	sys.exit(-1)

	date = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M')

	target_dir = "Mendeley cleaned" # Change this one to change which data we're processing
	directory_path = "../cleaned datasets/" + target_dir

	output_file = f"../featuresets/{target_dir}_{date}.csv"
    
	gen_training_matrix(directory_path, output_file, cols_to_ignore = -1)
# Out:
# Using file subject1-label-1-cleaned.csv
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 4.156647167873053e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 4.183375861243095e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 3.855029937524536e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 7.17287687645379e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 3.403015992305413e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 5.260475848511868e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 4.866446847869071e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 2.8983027792558707e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 3.401762431345638e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 6.69702135859476e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 6.621606841744914e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 7.007539786090262e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 2.920624453192995e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 4.974144589435261e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 5.527779724116335e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 2.794226533323234e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 6.090079949808642e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 5.893472321311143e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 5.737337952040683e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 3.2683696803618475e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 3.4497143326950064e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 2.373135415637111e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 2.679342095241018e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 1.1514992148090844e-12
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 2.667662379018661e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 2.299318144174654e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 3.053109463854463e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 6.999211402467159e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 7.749835283257655e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 9.126354684514785e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 2.864189682159516e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 2.9589210064568607e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 4.371750163329207e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 3.5793847529447626e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 1.0554113877290342e-12
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 1.21174245553904e-12
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 6.216140058462511e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 6.846824206701422e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 2.354103129660807e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 2.3000246694187844e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 2.65661210395267e-13
#   return f(*arrays, *other_args, **kwargs)
# resulting vector shape for the file (334, 990)
# Using file subject1-label-2-cleaned.csv
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 2.838681786016024e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 3.225748868249952e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 2.3817662737071637e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 2.554736247589165e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 7.189695281215957e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 7.567244955019529e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 2.9765791291653464e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 3.193324650827578e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 2.3138893001864823e-13
#   return f(*arrays, *other_args, **kwargs)
# c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err =
:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226: RuntimeWarning: logm result may be inaccurate, approximate err = 6.518469090715009e-13
#   return f(*arrays, *other_args, **kwargs)
# resulting vector shape for the file (249, 990)
# FINAL_MATRIX (2343, 990)

# %%
#This is the generating matrix code for our own data
def gen_training_matrix(directory_path, output_file, cols_to_ignore):
	# Initialise return matrix
	FINAL_MATRIX = None
	
	for x in os.listdir(directory_path):

		# Ignore non-CSV files
		if not x.lower().endswith('.csv'):
			continue
		
		# For safety we'll ignore files containing the substring "test". 
		# [Test files should not be in the dataset directory in the first place]
		if 'test' in x.lower():
			continue
		try:
			name, state, _, _ = x[:-4].split('-')
		except:
			print ('Wrong file name', x)
			sys.exit(-1)
		if state.lower() == 'Marshall':
			state = 2.
		elif state.lower() == 'label':
			state = 1.
		elif state.lower() == 'Kenzo':
			state = 0.
		else:
			print ('Wrong file name', x)
			sys.exit(-1)
			
		print ('Using file', x)
		full_file_path = directory_path  +   '/'   + x
		vectors, header = generate_feature_vectors_from_samples(file_path = full_file_path, 
														        nsamples = 150, 
																period = 1.,
																state = state,
														        remove_redundant = True,
																cols_to_ignore = cols_to_ignore)
		
		print ('resulting vector shape for the file', vectors.shape)
		
		
		if FINAL_MATRIX is None:
			FINAL_MATRIX = vectors
		else:
			FINAL_MATRIX = np.vstack( [ FINAL_MATRIX, vectors ] )

	print ('FINAL_MATRIX', FINAL_MATRIX.shape)
	
	# Shuffle rows
	# np.random.shuffle(FINAL_MATRIX)
	
	# Save to file
	np.savetxt(output_file, FINAL_MATRIX, delimiter = ',',
			header = ','.join(header), 
			comments = '')

	return None


if __name__ == '__main__':
	
	
	# if len(sys.argv) < 3: # For use in calling the function from the command line
	# 	print ('arg1: input dir\narg2: output file')
	# 	sys.exit(-1)

	date = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M')

	target_dir = "local datasets" # Change this one to change which data we're processing
	directory_path = "../cleaned datasets/" + target_dir

	output_file = f"../featuresets/{target_dir}_{date}.csv"
    
	gen_training_matrix(directory_path, output_file, cols_to_ignore = [5,6,7,8,9])
# Out:
# Using file subjectNatalie-label-1-cleaned.csv
# Slice too short break
# Slice too short break
# Index break
# Index break
# Slice too short break
# End of recording break
# resulting vector shape for the file (67, 990)
# FINAL_MATRIX (67, 990)

# %%
# This is the generating matrix code for the Emotion data
def gen_training_matrix(directory_path, output_file, cols_to_ignore):
	# Initialise return matrix
	FINAL_MATRIX = None
	
	for x in os.listdir(directory_path):

		# Ignore non-CSV files
		if not x.lower().endswith('.csv'):
			continue
		
		# For safety we'll ignore files containing the substring "test". 
		# [Test files should not be in the dataset directory in the first place]
		if 'test' in x.lower():
			continue
		try:
			name, _ ,state, _ = x[:-4].split('-')
		except:
			print ('Wrong file name', x)
			sys.exit(-1)
		if state.lower() == '1': #Anger
			state = 1.
		elif state.lower() == '2': #Fear
			state = 2.
		elif state.lower() == '3': #Happiness
			state = 3.
		elif state.lower() == '4': #Sadness
			state = 4.
		else:
			print ('Wrong file name', x)
			sys.exit(-1)
			
		print ('Using file', x)
		full_file_path = directory_path  +   '/'   + x
		vectors, header = generate_feature_vectors_from_samples(file_path = full_file_path, 
														        nsamples = 150, 
																period = 1.,
																state = state,
														        remove_redundant = True,
																cols_to_ignore = cols_to_ignore)
		
		print ('resulting vector shape for the file', vectors.shape)
		
		
		if FINAL_MATRIX is None:
			FINAL_MATRIX = vectors
		else:
			FINAL_MATRIX = np.vstack( [ FINAL_MATRIX, vectors ] )

	print ('FINAL_MATRIX', FINAL_MATRIX.shape)
	
	# Shuffle rows
	# np.random.shuffle(FINAL_MATRIX)
	
	# Save to file
	np.savetxt(output_file, FINAL_MATRIX, delimiter = ',',
			header = ','.join(header), 
			comments = '')

	return None


if __name__ == '__main__':
	
	
	# if len(sys.argv) < 3: # For use in calling the function from the command line
	# 	print ('arg1: input dir\narg2: output file')
	# 	sys.exit(-1)

	date = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M')

	target_dir = "Emotion cleaned" # Change this one to change which data we're processing
	directory_path = "../cleaned datasets/" + target_dir

	output_file = f"../featuresets/{target_dir}_{date}.csv"
    
	gen_training_matrix(directory_path, output_file, cols_to_ignore = [5,6,7,8,9])
# Out:
# Using file subject1-label-1-cleaned.csv
# Slice too short break
# resulting vector shape for the file (20, 990)
# Using file subject1-label-2-cleaned.csv
# Slice too short break
# resulting vector shape for the file (90, 990)
# Using file subject1-label-3-cleaned.csv
# Slice too short break
# resulting vector shape for the file (12, 990)
# Using file subject1-label-4-cleaned.csv
# Slice too short break
# resulting vector shape for the file (3, 990)
# Using file subject10-label-1-cleaned.csv
# Slice too short break
# resulting vector shape for the file (138, 990)
# Using file subject10-label-2-cleaned.csv
# Slice too short break
# resulting vector shape for the file (349, 990)
# Using file subject10-label-3-cleaned.csv
# Slice too short break
# resulting vector shape for the file (14, 990)
# Using file subject10-label-4-cleaned.csv
# Slice too short break
# resulting vector shape for the file (49, 990)
# Using file subject11-label-1-cleaned.csv
# Slice too short break
# resulting vector shape for the file (21, 990)
# Using file subject11-label-2-cleaned.csv
# Slice too short break
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 77
#      73 directory_path = "../cleaned datasets/" + target_dir
#      75 output_file = f"../featuresets/{target_dir}_{date}.csv"
# ---> 77 gen_training_matrix(directory_path, output_file, cols_to_ignore = [5,6,7,8,9])
#
# Cell In[7], line 35, in gen_training_matrix(directory_path, output_file, cols_to_ignore)
#      33 print ('Using file', x)
#      34 full_file_path = directory_path  +   '/'   + x
# ---> 35 vectors, header = generate_feature_vectors_from_samples(file_path = full_file_path,
#      36 												        nsamples = 150,
#      37 														period = 1.,
#      38 														state = state,
#      39 												        remove_redundant = True,
#      40 														cols_to_ignore = cols_to_ignore)
#      42 print ('resulting vector shape for the file', vectors.shape)
#      45 if FINAL_MATRIX is None:
#
# File c:\Users\Administrator\Documents\EEG_Social_Media_Analysis\code\EEG_feature_extraction.py:894, in generate_feature_vectors_from_samples(file_path, nsamples, period, state, remove_redundant, cols_to_ignore)
#     890 	if state is not None:
#     891 		 # Remove the label (last column) of previous vector
#     892 		previous_vector = previous_vector[:-1]
# --> 894 feat_names = ["Timestep"] + ["lag1_" + s for s in headers[:-1]] + headers
#     896 if remove_redundant:
#     897 	# Remove redundant lag window features
#     898 	to_rm = ["lag1_mean_q3_", "lag1_mean_q4_", "lag1_mean_d_q3q4_",
#     899 	         "lag1_max_q3_", "lag1_max_q4_", "lag1_max_d_q3q4_",
#     900 			 "lag1_min_q3_", "lag1_min_q4_", "lag1_min_d_q3q4_"]
#
# UnboundLocalError: cannot access local variable 'headers' where it is not associated with a value
