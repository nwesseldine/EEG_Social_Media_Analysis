# %%
import os, sys
import numpy as np
import datetime
from EEG_feature_extraction import generate_feature_vectors_from_samples
# Out:
# c:\Users\nwess\OneDrive\Documentos\EEG_Research\EEG_Social_Media_Analysis\code\EEG_feature_extraction.py:538: SyntaxWarning: invalid escape sequence '\s'
#   """

# %%
#This is the generating matrix code for the original github data
def gen_training_matrix(directory_path, output_file, cols_to_ignore):
	# Initialise return matrix
	FINAL_MATRIX = None
	
	for x in os.listdir(directory_path):

		# Ignore non-CSV files
		if not x.lower().endswith('.csv'):
			continue
		
		# For safety we'll ignore files containing the substring "test". 
		# [Test files should not be in the dataset directory in the first place]
		if 'test' in x.lower():
			continue
		try:
			name, state, _ = x[:-4].split('-')
		except:
			print ('Wrong file name', x)
			sys.exit(-1)
		if state.lower() == 'concentrating':
			state = 2.
		elif state.lower() == 'neutral':
			state = 1.
		elif state.lower() == 'relaxed':
			state = 0.
		else:
			print ('Wrong file name', x)
			sys.exit(-1)
			
		print ('Using file', x)
		full_file_path = directory_path  +   '/'   + x
		vectors, header = generate_feature_vectors_from_samples(file_path = full_file_path, 
														        nsamples = 150, 
																period = 1.,
																state = state,
														        remove_redundant = True,
																cols_to_ignore = cols_to_ignore)
		
		print ('resulting vector shape for the file', vectors.shape)
		
		
		if FINAL_MATRIX is None:
			FINAL_MATRIX = vectors
		else:
			FINAL_MATRIX = np.vstack( [ FINAL_MATRIX, vectors ] )

	print ('FINAL_MATRIX', FINAL_MATRIX.shape)
	
	# Shuffle rows
	# np.random.shuffle(FINAL_MATRIX)
	
	# Save to file
	np.savetxt(output_file, FINAL_MATRIX, delimiter = ',',
			header = ','.join(header), 
			comments = '')

	return None


if __name__ == '__main__':
	
	
	# if len(sys.argv) < 3: # For use in calling the function from the command line
	# 	print ('arg1: input dir\narg2: output file')
	# 	sys.exit(-1)

	date = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M')

	target_dir = "original_data" # Change this one to change which data we're processing
	directory_path = "../cleaned datasets/" + target_dir

	output_file = f"../featuresets/{target_dir}_{date}.csv"
    
	gen_training_matrix(directory_path, output_file, cols_to_ignore = -1)
# Out:
# Using file name-concentrating-1.csv
# resulting vector shape for the file (116, 989)
# Using file subjecta-concentrating-1.csv
# resulting vector shape for the file (116, 989)
# Using file subjecta-concentrating-2.csv
# resulting vector shape for the file (102, 989)
# Using file subjecta-neutral-1.csv
# resulting vector shape for the file (116, 989)
# Using file subjecta-neutral-2.csv
# resulting vector shape for the file (117, 989)
# Using file subjecta-relaxed-1.csv
# resulting vector shape for the file (116, 989)
# Using file subjecta-relaxed-2.csv
# resulting vector shape for the file (116, 989)
# Using file subjectb-concentrating-1.csv
# resulting vector shape for the file (86, 989)
# Using file subjectb-concentrating-2.csv
# resulting vector shape for the file (87, 989)
# Using file subjectb-neutral-1.csv
# resulting vector shape for the file (117, 989)
# Using file subjectb-neutral-2.csv
# resulting vector shape for the file (116, 989)
# Using file subjectb-relaxed-1.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 75
#      71 directory_path = "../cleaned datasets/" + target_dir
#      73 output_file = f"../featuresets/{target_dir}_{date}.csv"
# ---> 75 gen_training_matrix(directory_path, output_file, cols_to_ignore = -1)
#
# Cell In[11], line 33, in gen_training_matrix(directory_path, output_file, cols_to_ignore)
#      31 print ('Using file', x)
#      32 full_file_path = directory_path  +   '/'   + x
# ---> 33 vectors, header = generate_feature_vectors_from_samples(file_path = full_file_path,
#      34 												        nsamples = 150,
#      35 														period = 1.,
#      36 														state = state,
#      37 												        remove_redundant = True,
#      38 														cols_to_ignore = cols_to_ignore)
#      40 print ('resulting vector shape for the file', vectors.shape)
#      43 if FINAL_MATRIX is None:
#
# File c:\Users\nwess\OneDrive\Documentos\EEG_Research\EEG_Social_Media_Analysis\code\EEG_feature_extraction.py:829, in generate_feature_vectors_from_samples(file_path, nsamples, period, state, remove_redundant, cols_to_ignore)
#     784 """
#     785 Reads data from CSV file in "file_path" and extracts statistical features
#     786 for each time window of width "period".
#    (...)
#     826 	Reimplemented: [fcampelo]
#     827 """
#     828 # Read the matrix from file
# --> 829 matrix = matrix_from_csv_file(file_path)
#     831 # We will start at the very begining of the file
#     832 t = 0.
#
# File c:\Users\nwess\OneDrive\Documentos\EEG_Research\EEG_Social_Media_Analysis\code\EEG_feature_extraction.py:41, in matrix_from_csv_file(file_path)
#      23 def matrix_from_csv_file(file_path):
#      24 	"""
#      25 	Returns the data matrix given the path of a CSV file.
#      26
#    (...)
#      38
#      39 	"""
# ---> 41 	csv_data = np.genfromtxt(file_path, delimiter = ',')
#      42 	full_matrix = csv_data[1:]
#      43 	#headers = csv_data[0] # Commented since not used or returned [fcampelo]
#
# File c:\Users\nwess\anaconda3\Lib\site-packages\numpy\lib\npyio.py:1980, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    1978     fname = os_fspath(fname)
#    1979 if isinstance(fname, str):
# -> 1980     fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1981     fid_ctx = contextlib.closing(fid)
#    1982 else:
#
# File c:\Users\nwess\anaconda3\Lib\site-packages\numpy\lib\_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File c:\Users\nwess\anaconda3\Lib\site-packages\numpy\lib\_datasource.py:530, in DataSource.open(self, path, mode, encoding, newline)
#     528     if ext == 'bz2':
#     529         mode.replace("+", "")
# --> 530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
#     533     raise FileNotFoundError(f"{path} not found.")
#
# File <frozen codecs>:309, in __init__(self, errors)
#
# KeyboardInterrupt:

# %%
# This is the generating matrix code for Mendeley Data

def gen_training_matrix(directory_path, output_file, cols_to_ignore):
	# Initialise return matrix
	FINAL_MATRIX = None
	
	for x in os.listdir(directory_path):

		# Ignore non-CSV files
		if not x.lower().endswith('.csv'):
			continue
		
		# For safety we'll ignore files containing the substring "test". 
		# [Test files should not be in the dataset directory in the first place]
		if 'test' in x.lower():
			continue
		try:
			name, _ ,state, _ = x[:-4].split('-')
		except:
			print ('Wrong file name', x)
			sys.exit(-1)
		if state.lower() == '1':
			state = 1.
		elif state.lower() == '2':
			state = 2.
		elif state.lower() == '3':
			state = 3.
		else:
			print ('Wrong file name', x)
			sys.exit(-1)
			
		print ('Using file', x)
		full_file_path = directory_path  +   '/'   + x
		vectors, header = generate_feature_vectors_from_samples(file_path = full_file_path, 
														        nsamples = 150, 
																period = 1.,
																state = state,
														        remove_redundant = True,
																cols_to_ignore = cols_to_ignore)
		
		print ('resulting vector shape for the file', vectors.shape)
		
		
		if FINAL_MATRIX is None:
			FINAL_MATRIX = vectors
		else:
			FINAL_MATRIX = np.vstack( [ FINAL_MATRIX, vectors ] )

	print ('FINAL_MATRIX', FINAL_MATRIX.shape)
	
	# Shuffle rows
	# np.random.shuffle(FINAL_MATRIX)
	
	# Save to file
	np.savetxt(output_file, FINAL_MATRIX, delimiter = ',',
			header = ','.join(header), 
			comments = '')

	return None


if __name__ == '__main__':
	
	
	# if len(sys.argv) < 3: # For use in calling the function from the command line
	# 	print ('arg1: input dir\narg2: output file')
	# 	sys.exit(-1)

	date = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M')

	target_dir = "Mendeley cleaned" # Change this one to change which data we're processing
	directory_path = "../cleaned datasets/" + target_dir

	output_file = f"../featuresets/{target_dir}_{date}.csv"
    
	gen_training_matrix(directory_path, output_file, cols_to_ignore = -1)
# Out:
# Using file subject1-label-1-cleaned.csv
# resulting vector shape for the file (334, 989)
# Using file subject1-label-2-cleaned.csv
# resulting vector shape for the file (363, 989)
# Using file subject1-label-3-cleaned.csv
# resulting vector shape for the file (50, 989)
# Using file subject2-label-1-cleaned.csv
# resulting vector shape for the file (83, 989)
# Using file subject2-label-2-cleaned.csv
# resulting vector shape for the file (229, 989)
# Using file subject2-label-3-cleaned.csv
# resulting vector shape for the file (363, 989)
# Using file subject3-label-1-cleaned.csv
# resulting vector shape for the file (989,)
# Using file subject3-label-2-cleaned.csv
# resulting vector shape for the file (25, 989)
# Using file subject3-label-3-cleaned.csv
# resulting vector shape for the file (31, 989)
# Using file subject4-label-1-cleaned.csv
# resulting vector shape for the file (59, 989)
# Using file subject4-label-2-cleaned.csv
# resulting vector shape for the file (9, 989)
# Using file subject4-label-3-cleaned.csv
# resulting vector shape for the file (7, 989)
# Using file subject5-label-1-cleaned.csv
# resulting vector shape for the file (177, 989)
# Using file subject5-label-2-cleaned.csv
# resulting vector shape for the file (363, 989)
# Using file subject5-label-3-cleaned.csv
# resulting vector shape for the file (249, 989)
# FINAL_MATRIX (2343, 989)

# %%
#This is the genrating matrix code for our own data
def gen_training_matrix(directory_path, output_file, cols_to_ignore):
	# Initialise return matrix
	FINAL_MATRIX = None
	
	for x in os.listdir(directory_path):

		# Ignore non-CSV files
		if not x.lower().endswith('.csv'):
			continue
		
		# For safety we'll ignore files containing the substring "test". 
		# [Test files should not be in the dataset directory in the first place]
		if 'test' in x.lower():
			continue
		try:
			name, state, _, _ = x[:-4].split('-')
		except:
			print ('Wrong file name', x)
			sys.exit(-1)
		if state.lower() == 'Marshall':
			state = 2.
		elif state.lower() == 'label':
			state = 1.
		elif state.lower() == 'Kenzo':
			state = 0.
		else:
			print ('Wrong file name', x)
			sys.exit(-1)
			
		print ('Using file', x)
		full_file_path = directory_path  +   '/'   + x
		vectors, header = generate_feature_vectors_from_samples(file_path = full_file_path, 
														        nsamples = 150, 
																period = 1.,
																state = state,
														        remove_redundant = True,
																cols_to_ignore = cols_to_ignore)
		
		print ('resulting vector shape for the file', vectors.shape)
		
		
		if FINAL_MATRIX is None:
			FINAL_MATRIX = vectors
		else:
			FINAL_MATRIX = np.vstack( [ FINAL_MATRIX, vectors ] )

	print ('FINAL_MATRIX', FINAL_MATRIX.shape)
	
	# Shuffle rows
	# np.random.shuffle(FINAL_MATRIX)
	
	# Save to file
	np.savetxt(output_file, FINAL_MATRIX, delimiter = ',',
			header = ','.join(header), 
			comments = '')

	return None


if __name__ == '__main__':
	
	
	# if len(sys.argv) < 3: # For use in calling the function from the command line
	# 	print ('arg1: input dir\narg2: output file')
	# 	sys.exit(-1)

	date = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M')

	target_dir = "local datasets" # Change this one to change which data we're processing
	directory_path = "../cleaned datasets/" + target_dir

	output_file = f"../featuresets/{target_dir}_{date}.csv"
    
	gen_training_matrix(directory_path, output_file, cols_to_ignore = -1)
# Out:
# Using file subjectNatalie-label-1-cleaned.csv
# resulting vector shape for the file (48, 989)
# FINAL_MATRIX (48, 989)
